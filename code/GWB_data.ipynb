# %%
# %load_ext autoreload
# %autoreload 2

import scipy.io.wavfile as wav
import pyaudio
import wave
import sys
import pyaudio
import scipy
from scipy import signal

import numpy as np
import matplotlib.pylab as plt
from scipy.stats import norm
import matplotlib.mlab as mlab
from numpy import random

from playsound import *
from savetimeseries import *
from combinesignalnoise import *
from combinesignalsignal import *
from plottimeseries import *
from plotsignalnoisetimeseries import *
from plotsignalsignaltimeseries import *
from plotsignalsignalnoisetimeseries import *
from plothistogram import *
from plotpowerspectrum import *

# %matplotlib inline

# %% [markdown]
# # Different types of data=signal+noise

# %%
# white GWB in white noise (detector 1, A=0.1)
signalfile = 'whitenoise.txt'
noisefile  = 'whitenoise_det1.txt'
fileprefix = 'whitegwb_in_noise_det1_0.1'
A = 0.1

t, d, s, n = combinesignalnoise(signalfile, noisefile, A, fileprefix)
playsound(fileprefix)
plotsignalnoisetimeseries(t, s, d, t[0], t[-1], fileprefix)

# white GWB in white noise (detector 2, A=0.1)
signalfile = 'whitenoise.txt'
noisefile  = 'whitenoise_det2.txt'
fileprefix = 'whitegwb_in_noise_det2_0.1'
A = 0.1

t, d, s, n = combinesignalnoise(signalfile, noisefile, A, fileprefix)
playsound(fileprefix)
plotsignalnoisetimeseries(t, s, d, t[0], t[-1], fileprefix)

# %%
# confusion-limited BNS chirps in white noise (detector 1, A=0.03)
signalfile = 'chirpBNS10.txt'
noisefile  = 'whitenoise_det1.txt'
fileprefix = 'chirpBNS10_in_noise_det1_0.03'
A = 0.03

t, d, s, n = combinesignalnoise(signalfile, noisefile, A, fileprefix)
playsound(fileprefix)
plotsignalnoisetimeseries(t, s, d, t[0], t[-1], fileprefix)

# confusion-limited BNS chirps in white noise (detector 2, A=0.03)
signalfile = 'chirpBNS10.txt'
noisefile  = 'whitenoise_det2.txt'
fileprefix = 'chirpBNS10_in_noise_det2_0.03'
A = 0.03

t, d, s, n = combinesignalnoise(signalfile, noisefile, A, fileprefix)
playsound(fileprefix)
plotsignalnoisetimeseries(t, s, d, t[0], t[-1], fileprefix)

# %%
# popcorn BBH chirps in white noise (detector 1, A=0.001)
signalfile = 'chirpBBH10.txt'
noisefile  = 'whitenoise_det1.txt'
fileprefix = 'chirpBBH10_in_noise_det1_0.001'
A = 0.001

t, d, s, n = combinesignalnoise(signalfile, noisefile, A, fileprefix)
playsound(fileprefix)
plotsignalnoisetimeseries(t, s, d, t[0], t[-1], fileprefix)

# popcorn chirps in white noise (detector 2, A=0.001)
signalfile = 'chirpBBH10.txt'
noisefile  = 'whitenoise_det2.txt'
fileprefix = 'chirpBBH10_in_noise_det2_0.001'
A = 0.001

t, d, s, n = combinesignalnoise(signalfile, noisefile, A, fileprefix)
playsound(fileprefix)
plotsignalnoisetimeseries(t, s, d, t[0], t[-1], fileprefix)

# %%
# white GWB+confusion-limited BNS chirps in white noise (10 chirps, A= 0.1, 0.03)
signalfile1 = 'whitenoise.txt'
signalfile2 = 'chirpBNS10.txt'
fileprefix = 'whitegwb_chirpBNS10'
A1 = 1.
A2 = 0.3

t, s, s1, s2 = combinesignalsignal(signalfile1, signalfile2, A1, A2, fileprefix)
playsound(fileprefix)
plotsignalsignaltimeseries(t, s1, s2, t[0], t[-1], fileprefix)

# combine signal with noise in detector 1
signalfile = 'whitegwb_chirpBNS10.txt'
noisefile  = 'whitenoise_det1.txt'
fileprefix = 'whitegwb_chirpBNS10_in_noise_det1'
A = 0.1

t, d, s, n = combinesignalnoise(signalfile, noisefile, A, fileprefix)
playsound(fileprefix)
plotsignalsignalnoisetimeseries(t, A*s1, A*s2, d, t[0], t[-1], fileprefix)

# combine signal with noise in detector 2
signalfile = 'whitegwb_chirpBNS10.txt'
noisefile  = 'whitenoise_det2.txt'
fileprefix = 'whitegwb_chirpBNS10_in_noise_det2'
A = 0.1

t, d, s, n = combinesignalnoise(signalfile, noisefile, A, fileprefix)
playsound(fileprefix)
plotsignalsignalnoisetimeseries(t, A*s1, A*s2, d, t[0], t[-1], fileprefix)

# %%
# confusion-limited BNS chirps, popcorn BBH chirps in white noise (A= 0.003, 10 sec)
signalfile1 = 'chirpBNS50_10s.txt'
signalfile2 = 'chirpBBH10_10s.txt'
fileprefix = 'chirpBNS50BBH10'
A1 = 1.
A2 = 1.

t, s, s1, s2 = combinesignalsignal(signalfile1, signalfile2, A1, A2, fileprefix)
playsound(fileprefix)
plotsignalsignaltimeseries(t, s1, s2, t[0], t[-1], fileprefix)

# combine signal with noise in detector 1
signalfile = 'chirpBNS50BBH10.txt'
noisefile  = 'whitenoise_det1_10sec.txt'
fileprefix = 'chirpBNS50BBH10_in_noise_det1_0.003'
A = 0.003

t, d, s, n = combinesignalnoise(signalfile, noisefile, A, fileprefix)
playsound(fileprefix)
plotsignalsignalnoisetimeseries(t, A*s1, A*s2, d, t[0], t[-1], fileprefix)

# combine with noise in detector 2
signalfile = 'chirpBNS50BBH10.txt'
noisefile  = 'whitenoise_det2_10sec.txt'
fileprefix = 'chirpBNS50BBH10_in_noise_det2_0.003'
A = 0.003

t, d, s, n = combinesignalnoise(signalfile, noisefile, A, fileprefix)
playsound(fileprefix)
plotsignalsignalnoisetimeseries(t, A*s1, A*s2, d, t[0], t[-1], fileprefix)
